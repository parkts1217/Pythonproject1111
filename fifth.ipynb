# %% [markdown]
# padlet.com/jiminx/20260608
#
# git --version
#
# 등록
# git config user.name "parkts1217"
# git config user.email "parkts12174@gmail.com"
#
# 글로벌 등록
# git config --global user.name "parkts1217"
# git config --global user.email "parkts12174@gmail.com"
#
# 삭제
# git config --unset-all user.name
# git config --unset-all user.email
#
# 글로벌 삭제
# git config --global --unset-all user.name
# git config --global --unset-all user.email
#
#
# .gitignore : 해당파일에 명시 된 파일은 git hub 에 업로드 미 진행
#
# wrap

# %%
import requests
# Out:
# ge

# %%
from bs4 import BeautifulSoup

# %%
# %pip install requests
# Out:
# Requirement already satisfied: requests in c:\users\902_19\appdata\local\programs\python\python311\lib\site-packages (2.34.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\902_19\appdata\local\programs\python\python311\lib\site-packages (from requests) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\902_19\appdata\local\programs\python\python311\lib\site-packages (from requests) (3.18)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\users\902_19\appdata\local\programs\python\python311\lib\site-packages (from requests) (2.7.0)
# Requirement already satisfied: certifi>=2023.5.7 in c:\users\902_19\appdata\local\programs\python\python311\lib\site-packages (from requests) (2026.5.20)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# %pip install beautifulsoup4
# Out:
# Collecting beautifulsoup4
#   Downloading beautifulsoup4-4.15.0-py3-none-any.whl.metadata (3.8 kB)
# Collecting soupsieve>=1.6.1 (from beautifulsoup4)
#   Downloading soupsieve-2.8.4-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\users\902_19\appdata\roaming\python\python311\site-packages (from beautifulsoup4) (4.15.0)
# Downloading beautifulsoup4-4.15.0-py3-none-any.whl (109 kB)
#    ---------------------------------------- 0.0/109.9 kB ? eta -:--:--
#    -------------- ------------------------- 41.0/109.9 kB 1.9 MB/s eta 0:00:01
#    ---------------------------------------- 109.9/109.9 kB 3.1 MB/s eta 0:00:00
# Downloading soupsieve-2.8.4-py3-none-any.whl (37 kB)
# Installing collected packages: soupsieve, beautifulsoup4
# Successfully installed beautifulsoup4-4.15.0 soupsieve-2.8.4
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import requests
from bs4 import BeautifulSoup

# 1. 대상 URL 설정
url = "https://news.naver.com/section/105" # IT/과학 뉴스

# 2. HTTP GET 요청 (User-Agent 설정은 필수 - 봇 차단 방지)
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36"
}

response = requests.get(url, headers=headers)

# %%
response
# Out:
# <Response [200]>

# %%
response.status_code
# Out:
# 200

# %%
response.content
# Out:
# b'<!doctype html>\n<html lang="ko" data-useragent="Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36">\n\t<head>\n\t\t<meta charset="utf-8">\n\t\t<meta http-equiv="X-UA-Compatible" content="IE=edge">\n\t\t<meta name="referrer" contents="always">\n\t\t<meta http-equiv="refresh" content="600">\n\t\t<meta name="viewport" content="width=device-width, initial-scale=1.0, maximum-scale=1.0, minimum-scale=1.0, user-scalable=no" />\n\t\t<meta property="og:title" content="IT/\xea\xb3\xbc\xed\x95\x99 : \xeb\x84\xa4\xec\x9d\xb4\xeb\xb2\x84 \xeb\x89\xb4\xec\x8a\xa4">\n\t\t<meta property="og:type" content="website">\n\t\t<meta property="og:url" content="https://news.naver.com/section/105">\n\t\t<meta property="og:image" content="https://ssl.pstatic.net/static.news/image/news/ogtag/navernews_800x420_20221201.png">\n\t\t<meta property="og:description" content="\xeb\xaa\xa8\xeb\xb0\x94\xec\x9d\xbc, \xec\x9d\xb8\xed\x84\xb0\xeb\x84\xb7, SNS, \xed\x86\xb5\xec\x8b\xa0 \xeb\x93\xb1 IT/\xea\xb3\xbc\xed\x95\x99 \xeb\xb6\x84\xec\x95\xbc \xeb\x89\xb4\xec\x8a\xa4 \xec\xa0\x9c\xea\xb3\xb5">\n\t\t<meta property="og:article:author" content="\xeb\x84\xa4\xec\x9d\xb4\xeb\xb2\x84">\n\t\t<meta name="twitter:card" content="summary">\n\t\t<meta name="twitter:title" content="IT/\xea\xb3\xbc\xed\x95\x99 : \xeb\x84\xa4\xec\x9d\xb4\xeb\xb2\x84 \xeb\x89\xb4\xec\x8a\xa4">\n\t\t<meta name="twitter:site" content="\xeb\x84\xa4\xec\x9d\xb4\xeb\xb2\x84 \xeb\x89\xb4\xec\x8a\xa4">\n\t\t<meta name="twitter:creator" content="\xeb\x84\xa4\xec\x9d\xb4\xeb\xb2\x84 \xeb\x89\xb4\xec\x8a\xa4">\n\t\t<meta name="twitter:image" content="https://ssl.pstatic.net/static.news/image/news/ogtag/navernews_800x420_20221201.png">\n\t\t<meta name="twitter:description" content="\xeb\xaa\xa8\xeb\xb0\x94\xec\x9d\xbc, \xec\x9d\xb8\xed\x84\xb0\xeb\x84\xb7, SNS, \xed\x86\xb5\xec\x8b\xa0 \xeb\x93\xb1 IT/\xea\xb3\xbc\xed\x95\x99 \xeb\xb6\x84\xec\x95\xbc \xeb\x89\xb4\xec\x8a\xa4 \xec\xa0\x9c\xea\xb3\xb5">\n\t\t<title>IT/\xea\xb3\xbc\xed\x95\x99 : \xeb\x84\xa4\xec\x9d\xb4\xeb\xb2\x84 \xeb\x89\xb4\xec\x8a\xa4</title>\n\t\t\t<link rel="stylesheet" href="https://static-nnews.pstatic.net/css/min/20260611a/news.css">\n\t\t\t<link rel="shortcut icon" type="image/x-icon" href="https://ssl.pstatic.net/static.news/image/news/m/2023/08/21/favicon.ico" />\n\t\t\t<link rel="apple-touch-icon-precomposed" href="https://ssl.pstatic.net/static.news/image/news/m/2018/favicon/06/android_legacy_xxxhpdi_192x192.png" />\n\t\t\t<link rel="apple-touch-icon-precomposed" size="72x72" href="https://ssl.pstatic.net/static.news/image/news/m/2018/favicon/06/android_legacy_hdpi_72X72.png" />\n\t\t\t<link rel="apple-touch-icon-precomposed" size="96x96" href="https://ssl.pstatic.net/static.news/image/news/m/2018/favicon/06/android_legacy_xhdpi_96x96.png" />\n\t\t\t<link rel="apple-touch-icon-precomposed" size="144x144" href="https://ssl.pstatic.net/static.news/image/news/m/2018/favicon/06/android_legacy_xxhpdi_144x144.png" />\n\t\t\t<link rel="apple-touch-icon-precomposed" size="192x192" href="https://ssl.pstatic.net/static.news/image/news/m/2018/favicon/06/android_legacy_xxxhpdi_192x192.png" />\n\t\t\t\t\t<script>\n\t\t\tvar bSupportedIntersectionObserver = "IntersectionObserver" in window;\n\t\t</script>\n\t\t<script async src="https://ssl.pstatic.net/tveta/libs/glad/prod/gfp-core.js"></script>\n\t\t\t\t<script>\n\t\t\tvar g_ssc = nsc = "news.v3_sec";\n\t\t\tvar g_default_area = "itn";\n\n\t\t\tvar svr = "one-service-r-20260611-260611-165537-6cfbd69fdd-mvjmm";\n\t\t\tvar nelo = {\n\t\t\t\tname : "one-front",\n\t\t\t\turl : "https://kr-col-ext.nelo.navercorp.com/_store",\n\t\t\t\tsampleNumber : 100,\n\t\t\t\tmaxCount : 100,\n\t\t\t\tmaxSendMessage : "\xeb\xa1\x9c\xea\xb7\xb8 \xec\xa0\x84\xec\x86\xa1 \xec\xb5\x9c\xeb\x8c\x80\xec\xb9\x98 \xeb\x8f\x84\xeb\x8b\xac"\n\t\t\t};\n\t\t\tvar isGreendot = document.cookie.indexOf("MM_NEW=1") > -1;\n\t\t\tvar isNewGreendot = document.co ...

# %%
response.text
# Out:
# '<!doctype html>\n<html lang="ko" data-useragent="Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36">\n\t<head>\n\t\t<meta charset="utf-8">\n\t\t<meta http-equiv="X-UA-Compatible" content="IE=edge">\n\t\t<meta name="referrer" contents="always">\n\t\t<meta http-equiv="refresh" content="600">\n\t\t<meta name="viewport" content="width=device-width, initial-scale=1.0, maximum-scale=1.0, minimum-scale=1.0, user-scalable=no" />\n\t\t<meta property="og:title" content="IT/과학 : 네이버 뉴스">\n\t\t<meta property="og:type" content="website">\n\t\t<meta property="og:url" content="https://news.naver.com/section/105">\n\t\t<meta property="og:image" content="https://ssl.pstatic.net/static.news/image/news/ogtag/navernews_800x420_20221201.png">\n\t\t<meta property="og:description" content="모바일, 인터넷, SNS, 통신 등 IT/과학 분야 뉴스 제공">\n\t\t<meta property="og:article:author" content="네이버">\n\t\t<meta name="twitter:card" content="summary">\n\t\t<meta name="twitter:title" content="IT/과학 : 네이버 뉴스">\n\t\t<meta name="twitter:site" content="네이버 뉴스">\n\t\t<meta name="twitter:creator" content="네이버 뉴스">\n\t\t<meta name="twitter:image" content="https://ssl.pstatic.net/static.news/image/news/ogtag/navernews_800x420_20221201.png">\n\t\t<meta name="twitter:description" content="모바일, 인터넷, SNS, 통신 등 IT/과학 분야 뉴스 제공">\n\t\t<title>IT/과학 : 네이버 뉴스</title>\n\t\t\t<link rel="stylesheet" href="https://static-nnews.pstatic.net/css/min/20260611a/news.css">\n\t\t\t<link rel="shortcut icon" type="image/x-icon" href="https://ssl.pstatic.net/static.news/image/news/m/2023/08/21/favicon.ico" />\n\t\t\t<link rel="apple-touch-icon-precomposed" href="https://ssl.pstatic.net/static.news/image/news/m/2018/favicon/06/android_legacy_xxxhpdi_192x192.png" />\n\t\t\t<link rel="apple-touch-icon-precomposed" size="72x72" href="https://ssl.pstatic.net/static.news/image/news/m/2018/favicon/06/android_legacy_hdpi_72X72.png" />\n\t\t\t<link rel="apple-touch-icon-precomposed" size="96x96" href="https://ssl.pstatic.net/static.news/image/news/m/2018/favicon/06/android_legacy_xhdpi_96x96.png" />\n\t\t\t<link rel="apple-touch-icon-precomposed" size="144x144" href="https://ssl.pstatic.net/static.news/image/news/m/2018/favicon/06/android_legacy_xxhpdi_144x144.png" />\n\t\t\t<link rel="apple-touch-icon-precomposed" size="192x192" href="https://ssl.pstatic.net/static.news/image/news/m/2018/favicon/06/android_legacy_xxxhpdi_192x192.png" />\n\t\t\t\t\t<script>\n\t\t\tvar bSupportedIntersectionObserver = "IntersectionObserver" in window;\n\t\t</script>\n\t\t<script async src="https://ssl.pstatic.net/tveta/libs/glad/prod/gfp-core.js"></script>\n\t\t\t\t<script>\n\t\t\tvar g_ssc = nsc = "news.v3_sec";\n\t\t\tvar g_default_area = "itn";\n\n\t\t\tvar svr = "one-service-r-20260611-260611-165537-6cfbd69fdd-mvjmm";\n\t\t\tvar nelo = {\n\t\t\t\tname : "one-front",\n\t\t\t\turl : "https://kr-col-ext.nelo.navercorp.com/_store",\n\t\t\t\tsampleNumber : 100,\n\t\t\t\tmaxCount : 100,\n\t\t\t\tmaxSendMessage : "로그 전송 최대치 도달"\n\t\t\t};\n\t\t\tvar isGreendot = document.cookie.indexOf("MM_NEW=1") > -1;\n\t\t\tvar isNewGreendot = document.cookie.indexOf("MM_NEW=2") > -1;\n\t\t\tvar domain = "https://n.news.naver.com";\n\t\t\tvar ajaxDomain = "";\n\t\t\tvar newsDomain = "";\n\t\t\tvar layoutName = "section_home";\n\t\t\tvar layoutType = "section";\n\t\t\tvar isAvailableDarkMode = false;\n\t\t\tvar moduleLoadStatus = -1;\n\n\t\t\tvar article = {\n\t\t\t\t\n\t\t\t\tofficeId: "",\n\t\t\t\tarticleId: "",\n\t\t\t\tsectionId : "",\n\t\t\t\tgdid: "",\n\t\t\t\ttype: "",\n\t\t\t\tsectionInfo: {\n\t\t\t\t\tfirstSection: "",\n\t\t\t\t\tsecondSection: "",\n\t\t\t\t\tthirdSection: ""\n\t\t\t\t},\n\t\t\t\ttitle: document.title\n\t\t\t};\n\n\n\n\t\t\tvar office = {\n\t\t\t\tisChannel: false,\n\t\t\t\tisPressHome: false,\n\t\t\t\tname : "",\n\t\t\t\tcategory : ""\n\t\t\t};\n\n\t\t\tvar searchQuery = (function() {\n\t\t\t\tvar referrerLink = document.createElement("a");\n\t\t\t\tvar emptySe ...

# %%
# 3. HTML 파싱
soup = BeautifulSoup(response.text, "html.parser")

# 4. 데이터 추출 (CSS Selector 활용)
# 네이버 뉴스 구조에 따라 class명은 변경될 수 있음
news_list = soup.select(".sa_text_strong")

print((f" 오늘의 IT 뉴스 헤드라인 ({len(news_list)}건)"))

for idx, news in enumerate(news_list[:10],1):
    print(f"{idx}/ {news.get_text().strip()}")
# Out:
#  오늘의 IT 뉴스 헤드라인 (42건)
# 1/ 넥슨 ‘크레이지 아케이드’, 25년 만에 서비스 종료
# 2/ '개인정보 유출' 티빙에 이용자 1051명 집단소송 제기
# 3/ 후반기 국회 ‘식량안보법’ 제정될까…“개념부터 바로세워야”
# 4/ "9년 만에 마주 앉았다"…한-이탈리아, AI·기후·바이오 연구 협력 강화
# 5/ 이노스페이스, 한빛-나노 조사 종료…3분기 발사 재도전
# 6/ 네이버클라우드, 국방 AI 전략…옴니모달 전진 배치[테크스냅]
# 7/ 한미반도체, 스페이스X에 500억 베팅…‘테라팹’ 생태계 진입 포석
# 8/ 한미반도체, 스페이스X에 500억원 투자…"AI·우주 인프라 선제 대응"
# 9/ "안방까지 뜯을 돈 없어요"…노후 주택 늘자 벌어진 일
# 10/ 7.8조 KDDX 수주전 희비…한화오션, 근소한 차로 승기

# %%
soup.select()
soup.select_one()

# %%
import requests
from bs4 import BeautifulSoup

# 1. 대상 URL 설정
url = "https://finance.naver.com/news/mainnews.naver" # IT/과학 뉴스

# 2. HTTP GET 요청 (User-Agent 설정은 필수 - 봇 차단 방지)
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36"
}

response = requests.get(url, headers=headers)

# %%
import requests

url = "https://finance.naver.com/news/mainnews.naver"

response = requests.get(url)
response.status_code
# Out:
# 200

# %%
html = response.text

# %%
from bs4 import BeautifulSoup

soup = BeautifulSoup(html,'html.parser')

# %%
first_article = soup.select_one(".articleSubject > a")

# %%
first_article.attrs
# Out:
# {'href': '/news/news_read.naver?article_id=0001255172&office_id=215&mode=mainnews&type=&date=2026-06-12&page=1'}

# %%
first_article.text
# Out:
# "한주도 안 팔고 15년…30조 거머쥔 '존버 끝판왕'"

# %%
import requests
from bs4 import BeautifulSoup

url = "https://finance.naver.com/news/mainnews.naver"

response = requests.get(url)
response.status_code
html = response.text

soup = BeautifulSoup(html,'html.parser')
article_list = soup.select(".articleSubject > a")

#list_articleSummary = soup.select(".articleSummary")

for i in article_list:
    print(i.text)

# for j in list_articleSummary:
#     print(j)
# Out:
# [단독] TIGER 미국우주테크, 스페이스X 상장 당일 편입 철회
# 24일간 75조 팔던 외국인이 돌아왔다…하루 만에 1.2조 '폭풍 매수'
# AI 기대에 SK네트웍스 매수…삼성전자·SK하이닉스는 차익실현 [주식 초고수는 지금]
# 코스피, 장중 7%대 상승 8,300선…외국인 '순매수'로 견인
# 스페이스X 열풍에…레버리지·인버스 ETF 쏟아진다
# 개미, 레버리지 ETF에 2.8조  베팅
# "팔자 끝, 사자"...25일만에 돌아온 외국인 1.2조 순매수 종목은?
# “딜 가뭄에도 기회는 있다…K-뷰티·푸드 주목”
# "한화시스템, K-방산 밸류체인 장악"…KT&G, 변동장에 '확실한 방어주'로 추천 [株토피아]
# 삼성·하이닉스 수혜에 조선까지…비엠티 '쌍끌이 성장'
# 홈플러스에 필요한 2000억…MBK ‘보증’에도 메리츠 ‘선긋기’[마켓인]
# NH·삼성증권, IPO 선두 경쟁 치열…‘3위’ 미래에셋과 인수규모 2배 이상 격차
# '드디어 상장' 스페이스X 담을 우주테크 ETF에 이달 3조 '뭉칫돈'
# 마니커 '상한가'·교촌 '잠잠'…월드컵 수혜 '치킨주' 온도차 왜?
# 한주도 안 팔고 15년…30조 거머쥔 '존버 끝판왕'
# '삼전닉스' 언제까지 들고있어야 해?…"하반기 1만피 충분히 가능, 반도체가 끌어올릴 것"[긴급 증시전망]
# "종전 준비돼" 리스크 덜어내자 '쑥'…반도체 개미 '활짝'
# "세계 인구 90%가 K-헬스케어 누리는 시대 올 것"
# 키옥시아, 도요타 제치고 日시총 1위 등극 [도쿄나우]
# 코스피, 8%대 급등해 8천피 탈환…외인, 25거래일만에 '사자'(종합)

# %%
# 기사제목, 기사요약, 신문사, 작성날짜, 링크
# 하나의 태그만 가져와서 뽑고 select_one -> select

# %% [markdown]
# title =
# summary =
# press =
# wdate =
# link =
#
# print("title":title, "summary":summary, "press" : press, "wdate": wdate, "link" : link)

# %%
import requests
from bs4 import BeautifulSoup

url = "https://finance.naver.com/news/mainnews.naver"

response = requests.get(url)
response.status_code
html = response.text

soup = BeautifulSoup(html,'html.parser')

article_list = soup.select_one(".block1")



article_title = soup.select_one(".articleSubject")
summary = soup.select_one(".articleSummary")
press = soup.select_one(".press")
wdate = soup.select_one(".wdate")
# link = i.attrs
#print(article_title.text)
summary = summary.text.strip("")
print(summary)

summary = summary.split("\t")

print(summary)
# print(press.text)
# print(wdate.text)
cnt = 0


#list_articleSummary = soup.select(".articleSummary")

# for i in article_list:
#     title = i.text
#     summary =
#     press =
#     wdate = 
#     link = i.attrs

#     print(i)
#     print(i.text)
#     print()

# for j in list_articleSummary:
#     print(j)

#<a href="https://n.news.naver.com/mnews/article/215/0001255172" target="_blank">한주도 안 팔고 15년…30조 거머쥔 '존버 끝판왕'</a>
# Out:
# 										MSCI 선진지수 관찰대상국 편입가능성 60%…환율 단기내 하락 어려워" 노무라증권은 12일 "반도체 슈퍼 사이클은 이제 막 시작됐다"..
# 										연합뉴스
# |
# 2026-06-12 13:43:24
#
# ['\n\t\t\t\t\t\t\t\t\t\tMSCI 선진지수 관찰대상국 편입가능성 60%…환율 단기내 하락 어려워" 노무라증권은 12일 "반도체 슈퍼 사이클은 이제 막 시작됐다"..\n\t\t\t\t\t\t\t\t\t\t연합뉴스 \n|\n2026-06-12 13:43:24\n']

# %%
import requests
from bs4 import BeautifulSoup

url = "https://finance.naver.com/news/mainnews.naver"

response = requests.get(url)
response.status_code
html = response.text

soup = BeautifulSoup(html,'html.parser')

article = soup.select_one(".block1")

title = article.select_one('.articleSubject > a').text
summary = article.select_one('.articleSummary').contents[0].text.strip()
press = article.select_one('.press').text.strip()
wdate = article.select_one('.wdate').text
link = article.select_one('.articleSubject > a').attrs['href']
temp = link.split("&")
temp_article_id = temp[0].split("=")
article_id = temp_article_id[1]
temp_office_id = temp[1].split("=")
office_id = temp_office_id[1]
temp_link = "https://n.news.naver.com/mnews/article/" + office_id + "/" + article_id
temp_link

print(f'"title":{title}, "summary":{summary}, "press" : {press}, "wdate": {wdate}, "link" : {temp_link}')
# Out:
# "title":'형님' 삼전닉스 따라 장비주 줄줄이 상한가…"슈퍼사이클 초기 진입", "summary":반도체 투자 심리가 돌아오면서 반도체 장비주들이 줄이어 상한가를 기록하고 있다. 삼성전자와 SK하이닉스 등 대형 반도체 기업들이 생산 .., "press" : 머니투데이, "wdate": 2026-06-12 14:08:50, "link" : https://n.news.naver.com/mnews/article/008/0005371117

# %% [markdown]
# <a href="https://n.news.naver.com/mnews/article/008/0005371117" target="_blank">반도체주 뛰자 장비주 난다…원익IPS·HPSP 상한가</a>

# %%
summary.contents[0].text.strip()
# Out:
# '국내 반도체 소부장(소재·부품·장비) 종목들이 12일 일제히 급등했다. 최근 인공지능(AI) 소부장 업종에 대한 투자심리가 개선되면서 ..'

# %%
import requests
from bs4 import BeautifulSoup

url = "https://finance.naver.com/news/mainnews.naver"

response = requests.get(url)
response.status_code
html = response.text

soup = BeautifulSoup(html,'html.parser')

article = soup.select_one(".block1")

title = article.select_one('.articleSubject > a').text
summary = article.select_one('.articleSummary').contents[0].text.strip()
press = article.select_one('.press').text.strip()
wdate = article.select_one('.wdate').text
link = article.select_one('.articleSubject > a').attrs['href']

article_id = link.split('=')[1].split('&')[0]
office_id = link.split('office_id=')[1].split('&')[0]
link = f"https://n.news.naver.com/mnews/article/{office_id}/{article_id}"

print(f'"title":{title}, "summary":{summary}, "press" : {press}, "wdate": {wdate}, "link" : {link}')
# Out:
# "title":'형님' 삼전닉스 따라 장비주 줄줄이 상한가…"슈퍼사이클 초기 진입", "summary":반도체 투자 심리가 돌아오면서 반도체 장비주들이 줄이어 상한가를 기록하고 있다. 삼성전자와 SK하이닉스 등 대형 반도체 기업들이 생산 .., "press" : 머니투데이, "wdate": 2026-06-12 14:08:50, "link" : https://n.news.naver.com/mnews/article/008/0005371117

# %%
import requests
from bs4 import BeautifulSoup

url = "https://finance.naver.com/news/mainnews.naver"

response = requests.get(url)
print(response.status_code)
html = response.text

soup = BeautifulSoup(html,'html.parser')
articles = soup.select(".block1")

data = []

for article in articles:
    title = article.select_one('.articleSubject > a').text
    summary = article.select_one('.articleSummary').contents[0].text.strip()
    press = article.select_one('.press').text.strip()
    wdate = article.select_one('.wdate').text
    link = article.select_one('.articleSubject > a').attrs['href']

    article_id = link.split('=')[1].split('&')[0]
    office_id = link.split('office_id=')[1].split('&')[0]
    link = f"https://n.news.naver.com/mnews/article/{office_id}/{article_id}"

    #print(f'"title":{title}, "summary":{summary}, "press" : {press}, "wdate": {wdate}, "link" : {link}')
    data.append({"title":title, "summary": summary, "press" : press, "wdate": wdate, "link" : link})
print(data)
# Out:
# 200
# [{'title': '코스피 1만1000 간다는 노무라...“반도체 슈퍼사이클 이제 막 시작됐다”', 'summary': '일본 노무라증권이 인공지능(AI) 확산에 따른 메모리 반도체 수요 급증을 근거로 “반도체 슈퍼사이클은 이제 막 시작됐다”고 진단했다. ..', 'press': '매일경제', 'wdate': '2026-06-12 14:51:06', 'link': 'https://n.news.naver.com/mnews/article/009/0005693024'}, {'title': '돌아온 외국인…긴축 공포 이긴 증시', 'summary': '유럽을 비롯한 주요국 중앙은행의 기준금리 인상 움직임이 포착된 가운데, 증시는 미국과 이란의 종전 협상 가능성에 긴축 공포를 이기고 달..', 'press': '한국경제TV', 'wdate': '2026-06-12 14:47:10', 'link': 'https://n.news.naver.com/mnews/article/215/0001255208'}, {'title': "스페이스X 잡아라…미래·한투 '우주테크' ETF 경쟁 후끈[체크!ETF]", 'summary': '는 주요 상품 수익률과 정보를 정리, 투자 궁금증을 해소하는 코너입니다. 역대 최대규모의 IPO를 추진하는 스페이스X의 상장이 초읽기에..', 'press': '동행미디어 시대', 'wdate': '2026-06-12 14:37:59', 'link': 'https://n.news.naver.com/mnews/article/417/0001147306'}, {'title': '\'형님\' 삼전닉스 따라 장비주 줄줄이 상한가…"슈퍼사이클 초기 진입"', 'summary': '반도체 투자 심리가 돌아오면서 반도체 장비주들이 줄이어 상한가를 기록하고 있다. 삼성전자와 SK하이닉스 등 대형 반도체 기업들이 생산 ..', 'press': '머니투데이', 'wdate': '2026-06-12 14:08:50', 'link': 'https://n.news.naver.com/mnews/article/008/0005371117'}, {'title': 'AI 소부장株 들썩…HPSP·원익IPS 나란히 상한가 [이런국장 저런주식]', 'summary': '국내 반도체 소부장(소재·부품·장비) 종목들이 12일 일제히 급등했다. 최근 인공지능(AI) 소부장 업종에 대한 투자심리가 개선되면서 ..', 'press': '서울경제', 'wdate': '2026-06-12 14:04:07', 'link': 'https://n.news.naver.com/mnews/article/011/0004630506'}, {'title': '"반도체 슈퍼사이클 이제 막 시작…코스피 1만 간다"', 'summary': '노무라증권이 인공지능(AI) 확산에 따른 메모리 수요 급증을 근거로 반도체 슈퍼 사이클이 본격적인 상승 구간에 진입했다고 진단했다. A..', 'press': '한국경제TV', 'wdate': '2026-06-12 13:56:16', 'link': 'https://n.news.naver.com/mnews/article/215/0001255193'}, {'title': '노무라 "반도체 사이클 이제 막 시작…방산·車도 증시 이끌것"', 'summary': 'MSCI 선진지수 관찰대상국 편입가능성 60%…환율 단기내 하락 어려워" 노무라증권은 12일 "반도체 슈퍼 사이클은 이제 막 시작됐다"..', 'press': '연합뉴스', 'wdate': '2026-06-12 13:43:24', 'link': 'https://n.news.naver.com/mnews/article/001/0016135718'}, {'title': '與 "DIP 조달" vs 메리츠證 "김병주 MBK회장 보증 필요"…홈플러스 회생 교착', 'summary': '민주당 을지로위원회 11일 메리츠증권 항의방문 메리츠, 홈플러스 DIP 요청 이후 같은 입장 반복 기업회생 절차를 밟고 있는 홈플러스 ..', 'press': '더팩트', 'wdate': '2026-06-12 13:36:16', 'link': 'https://n.news.naver.com/mnews/article/629/0000507178'}, {'title': '\'법정관리 기업을 글로벌 주역으로\' 남민우 회장 "디티에스 상장, 성장의 결실"', 'summary': '다산네트웍스가 자회사 디티에스(DTS)의 코스닥 상장을 둘러싼 중복상장 논란의 정면돌파에 나섰다. 남민우 다산그룹 회장은 12일 오전 ..', 'press': '머니투데이', 'wdate': '2026-06-12 13:31:52', 'link': 'https://n.news.naver.com/mnews/article/008/0005371102'}, {'title': '-1천만원 주식 손실, 6개월 숨긴 아내…"신뢰 손상 vs 각자 자산" 갑론을박', 'summary': '주식 투자로 1천만 원이 넘는 자산 손실을 본 사실을 반년 동안이나 남편에게 숨겨온 아내의 사연을 두고 온라인상에서 뜨거운 설전이 벌어..', 'press': '이코노미스트', 'wdate': '2026-06-12 13:29:07', 'link': 'https://n.news.naver.com/mnews/article/243/0000099050'}, {'title': '[단독] TIGER 미국우주테크, 스페이스X 상장 당일 편입 철회', 'summary': '미래에셋자산운용이 ‘TIGER 미국우주테크’ 상장지수펀드(ETF)의 스페이스X 상장 당일 편입 계획을 철회했다. 기존 계획대로 상장 후..', 'press': '서울경제', 'wdate': '2026-06-12 11:56:13', 'link': 'https://n.news.naver.com/mnews/article/011/0004630477'}, {'title': "24일간 75조 팔던 외국인이 돌아왔다…하루 만에 1.2조 '폭풍 매수'", 'summary': '24거래일 연속 대규모 매도에 나섰던 외국인 투자자들이 코스피 시장으로 돌아온 것으로 보인다. 외국인은 하루 만에 1조원이 넘는 순매수..', 'press': '파이낸셜뉴스', 'wdate': '2026-06-12 11:37:18', 'link': 'https://n.news.naver.com/mnews/article/014/0005534146'}, {'title': 'AI 기대에 SK네트웍스 매수…삼성전자·SK하이닉스는 차익실현 [주식 초고수는 지금]', 'summary': '미래에셋증권에서 거래하는 고수익 투자자들이 12일 가장 많이 순매수한 종목은 SK네트웍스, 주성엔지니어링, 에이플러스바이오 순으로 집계..', 'press': '서울경제', 'wdate': '2026-06-12 11:35:11', 'link': 'https://n.news.naver.com/mnews/article/011/0004630472'}, {'title': "코스피, 장중 7%대 상승 8,300선…외국인 '순매수'로 견인", 'summary': "이란전쟁 종전 기대감에 시장 전반 온기…코스피 '매수 사이드카' 삼전 11% 급등·하이닉스도 7%대↑…코스닥도 상승세 VKOSPI 또 ..", 'press': '연합뉴스', 'wdate': '2026-06-12 11:28:27', 'link': 'https://n.news.naver.com/mnews/article/001/0016135153'}, {'title': '스페이스X 열풍에…레버리지·인버스 ETF 쏟아진다', 'summary': "올해 '기업공개(IPO) 최대어' 꼽히는 스페이스X가 상장하면 레버리지·인버스 등 관련 상장지수펀드(ETF) 상품들이 대거 시장에 쏟아..", 'press': '아시아경제', 'wdate': '2026-06-12 11:26:22', 'link': 'https://n.news.naver.com/mnews/article/277/0005775608'}, {'title': '개미, 레버리지 ETF에 2.8조  베팅', 'summary': '순매수 1~4위, 모두 레버리지 상품 변동성 증시서 손실 커져…투자 신중 “FOMC 등 변동성 확대 ...

# %%
# %pip install pandas
# Out:
# Collecting pandas
#   Downloading pandas-3.0.3-cp311-cp311-win_amd64.whl.metadata (19 kB)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\902_19\appdata\local\programs\python\python311\lib\site-packages (from pandas) (2.4.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\902_19\appdata\roaming\python\python311\site-packages (from pandas) (2.9.0.post0)
# Collecting tzdata (from pandas)
#   Downloading tzdata-2026.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: six>=1.5 in c:\users\902_19\appdata\roaming\python\python311\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Downloading pandas-3.0.3-cp311-cp311-win_amd64.whl (9.9 MB)
#    ---------------------------------------- 0.0/9.9 MB ? eta -:--:--
#     --------------------------------------- 0.2/9.9 MB 5.3 MB/s eta 0:00:02
#    -- ------------------------------------- 0.7/9.9 MB 8.4 MB/s eta 0:00:02
#    ---- ----------------------------------- 1.2/9.9 MB 9.4 MB/s eta 0:00:01
#    ------ --------------------------------- 1.7/9.9 MB 10.0 MB/s eta 0:00:01
#    --------- ------------------------------ 2.3/9.9 MB 10.3 MB/s eta 0:00:01
#    ----------- ---------------------------- 2.8/9.9 MB 10.6 MB/s eta 0:00:01
#    ------------- -------------------------- 3.4/9.9 MB 10.8 MB/s eta 0:00:01
#    --------------- ------------------------ 3.9/9.9 MB 11.3 MB/s eta 0:00:01
#    ----------------- ---------------------- 4.5/9.9 MB 11.4 MB/s eta 0:00:01
#    -------------------- ------------------- 5.0/9.9 MB 11.4 MB/s eta 0:00:01
#    ---------------------- ----------------- 5.6/9.9 MB 11.4 MB/s eta 0:00:01
#    ------------------------ --------------- 6.1/9.9 MB 11.4 MB/s eta 0:00:01
#    -------------------------- ------------- 6.6/9.9 MB 11.5 MB/s eta 0:00:01
#    ---------------------------- ----------- 7.2/9.9 MB 11.5 MB/s eta 0:00:01
#    ------------------------------- -------- 7.7/9.9 MB 11.5 MB/s eta 0:00:01
#    --------------------------------- ------ 8.3/9.9 MB 11.5 MB/s eta 0:00:01
#    ----------------------------------- ---- 8.8/9.9 MB 11.5 MB/s eta 0:00:01
#    ------------------------------------- -- 9.3/9.9 MB 11.5 MB/s eta 0:00:01
#    ---------------------------------------  9.9/9.9 MB 11.5 MB/s eta 0:00:01
#    ---------------------------------------- 9.9/9.9 MB 11.3 MB/s eta 0:00:00
# Downloading tzdata-2026.2-py2.py3-none-any.whl (349 kB)
#    ---------------------------------------- 0.0/349.3 kB ? eta -:--:--
#    --------------------------------------- 349.3/349.3 kB 10.6 MB/s eta 0:00:00
# Installing collected packages: tzdata, pandas
# Successfully installed pandas-3.0.3 tzdata-2026.2
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd

df = pd.DataFrame(data)
df
# Out:
#                                                 title  \
# 0          코스피 1만1000 간다는 노무라...“반도체 슈퍼사이클 이제 막 시작됐다”
# 1                                 돌아온 외국인…긴축 공포 이긴 증시
# 2            스페이스X 잡아라…미래·한투 '우주테크' ETF 경쟁 후끈[체크!ETF]
# 3              '형님' 삼전닉스 따라 장비주 줄줄이 상한가…"슈퍼사이클 초기 진입"
# 4           AI 소부장株 들썩…HPSP·원익IPS 나란히 상한가 [이런국장 저런주식]
# 5                       "반도체 슈퍼사이클 이제 막 시작…코스피 1만 간다"
# 6                  노무라 "반도체 사이클 이제 막 시작…방산·車도 증시 이끌것"
# 7     與 "DIP 조달" vs 메리츠證 "김병주 MBK회장 보증 필요"…홈플러스 회생 교착
# 8        '법정관리 기업을 글로벌 주역으로' 남민우 회장 "디티에스 상장, 성장의 결실"
# 9        -1천만원 주식 손실, 6개월 숨긴 아내…"신뢰 손상 vs 각자 자산" 갑론을박
# 10               [단독] TIGER 미국우주테크, 스페이스X 상장 당일 편입 철회
# 11           24일간 75조 팔던 외국인이 돌아왔다…하루 만에 1.2조 '폭풍 매수'
# 12    AI 기대에 SK네트웍스 매수…삼성전자·SK하이닉스는 차익실현 [주식 초고수는 지금]
# 13                코스피, 장중 7%대 상승 8,300선…외국인 '순매수'로 견인
# 14                        스페이스X 열풍에…레버리지·인버스 ETF 쏟아진다
# 15                             개미, 레버리지 ETF에 2.8조  베팅
# 16           "팔자 끝, 사자"...25일만에 돌아온 외국인 1.2조 순매수 종목은?
# 17                         “딜 가뭄에도 기회는 있다…K-뷰티·푸드 주목”
# 18  "한화시스템, K-방산 밸류체인 장악"…KT&G, 변동장에 '확실한 방어주'로 추천...
# 19                      삼성·하이닉스 수혜에 조선까지…비엠티 '쌍끌이 성장'
#
#                                               summary     press  \
# 0   일본 노무라증권이 인공지능(AI) 확산에 따른 메모리 반도체 수요 급증을 근거로 “...      매일경제
# 1   유럽을 비롯한 주요국 중앙은행의 기준금리 인상 움직임이 포착된 가운데, 증시는 미국...    한국경제TV
# 2   는 주요 상품 수익률과 정보를 정리, 투자 궁금증을 해소하는 코너입니다. 역대 최대...  동행미디어 시대
# 3   반도체 투자 심리가 돌아오면서 반도체 장비주들이 줄이어 상한가를 기록하고 있다. 삼...     머니투데이
# 4   국내 반도체 소부장(소재·부품·장비) 종목들이 12일 일제히 급등했다. 최근 인공지...      서울경제
# 5   노무라증권이 인공지능(AI) 확산에 따른 메모리 수요 급증을 근거로 반도체 슈퍼 사...    한국경제TV
# 6   MSCI 선진지수 관찰대상국 편입가능성 60%…환율 단기내 하락 어려워" 노무라증권...      연합뉴스
# 7   민주당 을지로위원회 11일 메리츠증권 항의방문 메리츠, 홈플러스 DIP 요청 이후 ...       더팩트
# 8   다산네트웍스가 자회사 디티에스(DTS)의 코스닥 상장을 둘러싼 중복상장 논란의 정면...     머니투데이
# 9   주식 투자로 1천만 원이 넘는 자산 손실을 본 사실을 반년 동안이나 남편에게 숨겨온...    이코노미스트
# 10  미래에셋자산운용이 ‘TIGER 미국우주테크’ 상장지수펀드(ETF)의 스페이스X 상장...      서울경제
# 11  24거래일 연속 대규모 매도에 나섰던 외국인 투자자들이 코스피 시장으로 돌아온 것으...    파이낸셜뉴스
# 12  미래에셋증권에서 거래하는 고수익 투자자들이 12일 가장 많이 순매수한 종목은 SK네...      서울경제
# 13  이란전쟁 종전 기대감에 시장 전반 온기…코스피 '매수 사이드카' 삼전 11% 급등·...      연합뉴스
# 14  올해 '기업공개(IPO) 최대어' 꼽히는 스페이스X가 상장하면 레버리지·인버스 등 ...     아시아경제
# 15  순매수 1~4위, 모두 레버리지 상품 변동성 증시서 손실 커져…투자 신중 “FOMC...     헤럴드경제
# 16  외국인 투자자가 25거래일 만에 순매수로 돌아섰다. 코스피 급등에 따른 리밸런싱이 ...     머니투데이
# 17  박남수 EY-파르테논 대표 인터뷰 상반기 글로벌 M&A ‘메가딜’ 위주 전개 반도체...     헤럴드경제
# 18  6월 12일 오전, 주요 증권사 리포트를 정리해드립니다. 한화시스템은 무기체계의 성...    파이낸셜뉴스
# 19  산업용 피팅·밸브 제조기업 비엠티가 반도체 설비투자 확대에 이어 친환경 선박 엔진 ...     머니투데이
#
#                   wdate                                               link
# 0   2026-06-12 14:51:06  https://n.news.naver.com/mnews/article/009/000...
# 1   2026-06-12 14:47:10  https://n.news.naver.com/mnews/article/215/000...
# 2   2026-06-12 14:37:59  https://n.news.naver.com/mnews/article/417/000...
# 3   2026-06-12 14:08:50  https://n.news.naver.com/mnews/article/008/000...
# 4   2026-06-12 14:04:07  https://n.news.naver.com/mnews/article/011/000...
# 5   2026-06-12 13:56:16  https://n.news.naver.com/mnews/article/215/000...
# 6   2026-06-12 13:43:24  https://n.news.naver.com/mnews/article/001/001...
# 7   2026-06-12 13:36:16  https://n.news.naver.com/mnews/article/629/000...
# 8   2026-06-12 13:31:52  https://n.news.naver.com/mnews/article/008/000...
# 9   2026-06-12 13:29:07  https://n.news.naver.com/mnews/article/243/000...
# 10  2026-06-12 11:56:13  https://n.news.naver.com/mnews/article/011/000...
# 11  2026-06-12 11:37:18  https://n.news.naver.com/mnews/article/014/000...
# 12  2026-06-12 11:35:11  https://n.news.naver.com/mnews/article/011/000...
# 13  2026-06-12 11:28:27  https://n.news.naver.com/mnews/article/001/001...
# 14  2026-06-12 11:26:22  https://n.news.naver.com/mnews/article/277/000...
# 15  2026-06-12 11:26:10  https://n.news.naver.com/mnews/article/016/000...
# 16  2026-06-12 11:24:05  https://n.news.naver.com/mnews/article/008/000...
# 17  2026-06-12 11:21:16  https://n.news.naver.com/mnews/article/016/000...
# 18  2026-06-12 11:10:13  https://n.news.naver.com/mnews/article/014/000...
# 19  2026-06-12 10:56:06  https://n.news.naver.com/mnews/article/008/000...

# %%
from datetime import datetime
date = datetime.now().strftime('%Y-%m-%d')
date
# Out:
# '2026-06-12'

# %%
import time
int(time.time())
# Out:
# 1781245037

# %%
import time
timestamp = time.time()

current_time = time.strftime("%H:%M:%S", time.localtime(timestamp))
print(current_time)
# Out:
# 15:20:05

# %%
file_name = f'data/네이버_오늘의_뉴스_{date}'
df.to_csv(f'{file_name}.csv')

# %%
https://apis.data.go.kr/1613000/RTMSDataSvcAptTrade/getRTMSDataSvcAptTrade?LAWD_CD=11110&DEAL_YMD=202605&serviceKey=

# %%
# %pip install xmltodict
# Out:
# Collecting xmltodict
#   Downloading xmltodict-1.0.4-py3-none-any.whl.metadata (14 kB)
# Downloading xmltodict-1.0.4-py3-none-any.whl (13 kB)
# Installing collected packages: xmltodict
# Successfully installed xmltodict-1.0.4
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import xmltodict

# %%
import requests

url = 'https://apis.data.go.kr/1613000/RTMSDataSvcAptTrade/getRTMSDataSvcAptTrade'
params = {
    'LAWD_CD': '44200',
     'DEAL_YMD' : '202604',
     'serviceKey' : '868f6a391a0c15b0923e6d292c7ae98ea287a3759b8c35154b1d3711e065a91f'
       }

response = requests.get(url, params=params)
response.status_code
# Out:
# 200

# %%
import xmltodict

response_data = xmltodict.parse(response.content)
response_data
# Out:
# {'response': {'header': {'resultCode': '000', 'resultMsg': 'OK'},
#   'body': {'items': {'item': [{'aptDong': '106',
#       'aptNm': '용화아이파크아파트',
#       'buildYear': '2014',
#       'buyerGbn': '개인',
#       'cdealDay': None,
#       'cdealType': None,
#       'dealAmount': '29,000',
#       'dealDay': '10',
#       'dealMonth': '4',
#       'dealYear': '2026',
#       'dealingGbn': '중개거래',
#       'estateAgentSggNm': '충남 아산시',
#       'excluUseAr': '84.9867',
#       'floor': '25',
#       'jibun': '1394',
#       'landLeaseholdGbn': 'N',
#       'rgstDate': '26.06.08',
#       'sggCd': '44200',
#       'slerGbn': '개인',
#       'umdNm': '용화동'},
#      {'aptDong': None,
#       'aptNm': '주은',
#       'buildYear': '2000',
#       'buyerGbn': '개인',
#       'cdealDay': None,
#       'cdealType': None,
#       'dealAmount': '14,900',
#       'dealDay': '30',
#       'dealMonth': '4',
#       'dealYear': '2026',
#       'dealingGbn': '중개거래',
#       'estateAgentSggNm': '충남 아산시',
#       'excluUseAr': '59.52',
#       'floor': '6',
#       'jibun': '229-71',
#       'landLeaseholdGbn': 'N',
#       'rgstDate': None,
#       'sggCd': '44200',
#       'slerGbn': '개인',
#       'umdNm': '풍기동'},
#      {'aptDong': None,
#       'aptNm': '대림이편한세상',
#       'buildYear': '2006',
#       'buyerGbn': '개인',
#       'cdealDay': None,
#       'cdealType': None,
#       'dealAmount': '24,000',
#       'dealDay': '25',
#       'dealMonth': '4',
#       'dealYear': '2026',
#       'dealingGbn': '중개거래',
#       'estateAgentSggNm': '충남 아산시',
#       'excluUseAr': '84.94',
#       'floor': '13',
#       'jibun': '625',
#       'landLeaseholdGbn': 'N',
#       'rgstDate': None,
#       'sggCd': '44200',
#       'slerGbn': '개인',
#       'umdNm': '모종동'},
#      {'aptDong': None,
#       'aptNm': '용화지구신도브래뉴',
#       'buildYear': '2009',
#       'buyerGbn': '개인',
#       'cdealDay': None,
#       'cdealType': None,
#       'dealAmount': '38,500',
#       'dealDay': '25',
#       'dealMonth': '4',
#       'dealYear': '2026',
#       'dealingGbn': '중개거래',
#       'estateAgentSggNm': '충남 아산시',
#       'excluUseAr': '126.567',
#       'floor': '23',
#       'jibun': '1623',
#       'landLeaseholdGbn': 'N',
#       'rgstDate': None,
#       'sggCd': '44200',
#       'slerGbn': '개인',
#       'umdNm': '용화동'},
#      {'aptDong': None,
#       'aptNm': '삼일원앙',
#       'buildYear': '1997',
#       'buyerGbn': '개인',
#       'cdealDay': None,
#       'cdealType': None,
#       'dealAmount': '5,900',
#       'dealDay': '30',
#       'dealMonth': '4',
#       'dealYear': '2026',
#       'dealingGbn': '중개거래',
#       'estateAgentSggNm': '충남 아산시',
#       'excluUseAr': '39.73',
#       'floor': '5',
#       'jibun': '427-1',
#       'landLeaseholdGbn': 'N',
#       'rgstDate': None,
#       'sggCd': '44200',
#       'slerGbn': '개인',
#       'umdNm': '음봉면 산동리'},
#      {'aptDong': '102',
#       'aptNm': '아산반도유보라',
#       'buildYear': '2016',
#       'buyerGbn': '개인',
#       'cdealDay': None,
#       'cdealType': None,
#       'dealAmount': '19,300',
#       'dealDay': '11',
#       'dealMonth': '4',
#       'dealYear': '2026',
#       'dealingGbn': '중개거래',
#       'estateAgentSggNm': '충남 아산시',
#       'excluUseAr': '59.9734',
#       'floor': '15',
#       'jibun': '1928',
#       'landLeaseholdGbn': 'N',
#       'rgstDate': '26.05.26',
#       'sggCd': '44200',
#       'slerGbn': '개인',
#       'umdNm': '온천동'},
#      {'aptDong': '206',
#       'aptNm': '서해그랑블2차',
#       'buildYear': '2009',
#       'buyerGbn': '개인',
#       'cdealDay': None,
#       'cdealType': None,
#       'dealAmount': '21,000',
#       'dealDay': '29',
#       'dealMonth': '4',
#       'dealYear': '2026',
#       'dealingGbn': '직거래',
#       'estateAgentSggNm': None,
#       'excluUseAr': '84.4973',
#       'floor': '13',
#       'jibun': '96-1',
#       'landLeaseholdGbn': 'N',
#       'rgstDate': '26.05.22',
#       'sggCd': '44200',
#       'slerGbn': '개인',
#       'umdNm': '권곡동'},
#      {'aptDong': None,
#       'aptNm': '샘마을',
#       'buildYear': '2001',
#       'buyerGbn': '개인',
#       'cdealDay': None,
#       'cdealType': None,
#       'dealAmount': '4,100',
#       'dealDay': '30',
#       'dealMonth': '4',
#       'dealYear': '2026',
#       'dealingGbn': '중개거래',
#       'estateAgentSggNm': '충남 아산시',
#       'excluUseAr': '39.27',
#       'floor': '12',
#       'jibun': '177-2',
#       'landLeaseholdGbn': 'N',
#       'rgstDate': None,
#       'sggCd': '44200',
#       'slerGbn': '개인',
#       'umdNm': '신창면 남성리'},
#      {'aptDong': None,
#       'aptNm': '아산온천미소지움아파트',
#       'buildYear': '2017',
#       'buyerGbn': '개인',
#       'cdealDay': None,
#       'cdealType': None,
#       'dealAmount': '21,000',
#       'dealDay': '20',
#       'dealMonth': '4',
#       'dealYear': '2026',
#       'dealingGbn': '중개거래',
#       'estateAgentSggNm': '충남 아산시',
#       'excluUseAr': '74.9754',
#       'floor': '2',
#       'jibun': '1935',
#       'landLeaseholdGbn': 'N',
#       'rgstDate': None,
#       'sggCd': '44200',
#       'slerGbn': '개인',
#       'umdNm': '온천동'},
#      {'aptDong': None,
#       'aptNm': '모종캐슬어울림3단지',
#       'buildYear': '2017',
#       'buyerGbn': '개인',
#       'cdealDay': None,
#       'cdealType': None,
#       'dealAmount': '33,000',
#       'dealDay': '5',
#       'dealMonth': '4',
#       'dealYear': '2026',
#       'dealingGbn': '중개거래',
#       'estateAgentSggNm': '충남 아산시',
#       'excluUseAr': '84.972',
#       'floor': '6',
#       'jibun': '643',
#       'landLeaseholdGbn': 'N',
#       'rgstDate': None,
#       'sggCd': '44200',
#       'slerGbn': '개인',
#       'umdNm': '모종동'}]},
#    'numOfRows': '10',
#    'pageNo': '1',
#    'totalCount': '460'}}}

# %%
items = response_data['response']['body']['items']['item'] 
items
# Out:
# [{'aptDong': '106',
#   'aptNm': '용화아이파크아파트',
#   'buildYear': '2014',
#   'buyerGbn': '개인',
#   'cdealDay': None,
#   'cdealType': None,
#   'dealAmount': '29,000',
#   'dealDay': '10',
#   'dealMonth': '4',
#   'dealYear': '2026',
#   'dealingGbn': '중개거래',
#   'estateAgentSggNm': '충남 아산시',
#   'excluUseAr': '84.9867',
#   'floor': '25',
#   'jibun': '1394',
#   'landLeaseholdGbn': 'N',
#   'rgstDate': '26.06.08',
#   'sggCd': '44200',
#   'slerGbn': '개인',
#   'umdNm': '용화동'},
#  {'aptDong': None,
#   'aptNm': '주은',
#   'buildYear': '2000',
#   'buyerGbn': '개인',
#   'cdealDay': None,
#   'cdealType': None,
#   'dealAmount': '14,900',
#   'dealDay': '30',
#   'dealMonth': '4',
#   'dealYear': '2026',
#   'dealingGbn': '중개거래',
#   'estateAgentSggNm': '충남 아산시',
#   'excluUseAr': '59.52',
#   'floor': '6',
#   'jibun': '229-71',
#   'landLeaseholdGbn': 'N',
#   'rgstDate': None,
#   'sggCd': '44200',
#   'slerGbn': '개인',
#   'umdNm': '풍기동'},
#  {'aptDong': None,
#   'aptNm': '대림이편한세상',
#   'buildYear': '2006',
#   'buyerGbn': '개인',
#   'cdealDay': None,
#   'cdealType': None,
#   'dealAmount': '24,000',
#   'dealDay': '25',
#   'dealMonth': '4',
#   'dealYear': '2026',
#   'dealingGbn': '중개거래',
#   'estateAgentSggNm': '충남 아산시',
#   'excluUseAr': '84.94',
#   'floor': '13',
#   'jibun': '625',
#   'landLeaseholdGbn': 'N',
#   'rgstDate': None,
#   'sggCd': '44200',
#   'slerGbn': '개인',
#   'umdNm': '모종동'},
#  {'aptDong': None,
#   'aptNm': '용화지구신도브래뉴',
#   'buildYear': '2009',
#   'buyerGbn': '개인',
#   'cdealDay': None,
#   'cdealType': None,
#   'dealAmount': '38,500',
#   'dealDay': '25',
#   'dealMonth': '4',
#   'dealYear': '2026',
#   'dealingGbn': '중개거래',
#   'estateAgentSggNm': '충남 아산시',
#   'excluUseAr': '126.567',
#   'floor': '23',
#   'jibun': '1623',
#   'landLeaseholdGbn': 'N',
#   'rgstDate': None,
#   'sggCd': '44200',
#   'slerGbn': '개인',
#   'umdNm': '용화동'},
#  {'aptDong': None,
#   'aptNm': '삼일원앙',
#   'buildYear': '1997',
#   'buyerGbn': '개인',
#   'cdealDay': None,
#   'cdealType': None,
#   'dealAmount': '5,900',
#   'dealDay': '30',
#   'dealMonth': '4',
#   'dealYear': '2026',
#   'dealingGbn': '중개거래',
#   'estateAgentSggNm': '충남 아산시',
#   'excluUseAr': '39.73',
#   'floor': '5',
#   'jibun': '427-1',
#   'landLeaseholdGbn': 'N',
#   'rgstDate': None,
#   'sggCd': '44200',
#   'slerGbn': '개인',
#   'umdNm': '음봉면 산동리'},
#  {'aptDong': '102',
#   'aptNm': '아산반도유보라',
#   'buildYear': '2016',
#   'buyerGbn': '개인',
#   'cdealDay': None,
#   'cdealType': None,
#   'dealAmount': '19,300',
#   'dealDay': '11',
#   'dealMonth': '4',
#   'dealYear': '2026',
#   'dealingGbn': '중개거래',
#   'estateAgentSggNm': '충남 아산시',
#   'excluUseAr': '59.9734',
#   'floor': '15',
#   'jibun': '1928',
#   'landLeaseholdGbn': 'N',
#   'rgstDate': '26.05.26',
#   'sggCd': '44200',
#   'slerGbn': '개인',
#   'umdNm': '온천동'},
#  {'aptDong': '206',
#   'aptNm': '서해그랑블2차',
#   'buildYear': '2009',
#   'buyerGbn': '개인',
#   'cdealDay': None,
#   'cdealType': None,
#   'dealAmount': '21,000',
#   'dealDay': '29',
#   'dealMonth': '4',
#   'dealYear': '2026',
#   'dealingGbn': '직거래',
#   'estateAgentSggNm': None,
#   'excluUseAr': '84.4973',
#   'floor': '13',
#   'jibun': '96-1',
#   'landLeaseholdGbn': 'N',
#   'rgstDate': '26.05.22',
#   'sggCd': '44200',
#   'slerGbn': '개인',
#   'umdNm': '권곡동'},
#  {'aptDong': None,
#   'aptNm': '샘마을',
#   'buildYear': '2001',
#   'buyerGbn': '개인',
#   'cdealDay': None,
#   'cdealType': None,
#   'dealAmount': '4,100',
#   'dealDay': '30',
#   'dealMonth': '4',
#   'dealYear': '2026',
#   'dealingGbn': '중개거래',
#   'estateAgentSggNm': '충남 아산시',
#   'excluUseAr': '39.27',
#   'floor': '12',
#   'jibun': '177-2',
#   'landLeaseholdGbn': 'N',
#   'rgstDate': None,
#   'sggCd': '44200',
#   'slerGbn': '개인',
#   'umdNm': '신창면 남성리'},
#  {'aptDong': None,
#   'aptNm': '아산온천미소지움아파트',
#   'buildYear': '2017',
#   'buyerGbn': '개인',
#   'cdealDay': None,
#   'cdealType': None,
#   'dealAmount': '21,000',
#   'dealDay': '20',
#   'dealMonth': '4',
#   'dealYear': '2026',
#   'dealingGbn': '중개거래',
#   'estateAgentSggNm': '충남 아산시',
#   'excluUseAr': '74.9754',
#   'floor': '2',
#   'jibun': '1935',
#   'landLeaseholdGbn': 'N',
#   'rgstDate': None,
#   'sggCd': '44200',
#   'slerGbn': '개인',
#   'umdNm': '온천동'},
#  {'aptDong': None,
#   'aptNm': '모종캐슬어울림3단지',
#   'buildYear': '2017',
#   'buyerGbn': '개인',
#   'cdealDay': None,
#   'cdealType': None,
#   'dealAmount': '33,000',
#   'dealDay': '5',
#   'dealMonth': '4',
#   'dealYear': '2026',
#   'dealingGbn': '중개거래',
#   'estateAgentSggNm': '충남 아산시',
#   'excluUseAr': '84.972',
#   'floor': '6',
#   'jibun': '643',
#   'landLeaseholdGbn': 'N',
#   'rgstDate': None,
#   'sggCd': '44200',
#   'slerGbn': '개인',
#   'umdNm': '모종동'}]

# %%
atm_data = []

for item in items:
   
    atm_data.append({"아파트명" : item['aptNm'], "법정동" : item['umdNm'], "거래금액" : item['dealAmount'], "전용면적" : item["excluUseAr"],"층" : item["floor"],"건축년도" : item['buildYear']})

print(atm_data)
# Out:
# [{'아파트명': '용화아이파크아파트', '법정동': '용화동', '거래금액': '29,000', '전용면적': '84.9867', '층': '25', '건축년도': '2014'}, {'아파트명': '주은', '법정동': '풍기동', '거래금액': '14,900', '전용면적': '59.52', '층': '6', '건축년도': '2000'}, {'아파트명': '대림이편한세상', '법정동': '모종동', '거래금액': '24,000', '전용면적': '84.94', '층': '13', '건축년도': '2006'}, {'아파트명': '용화지구신도브래뉴', '법정동': '용화동', '거래금액': '38,500', '전용면적': '126.567', '층': '23', '건축년도': '2009'}, {'아파트명': '삼일원앙', '법정동': '음봉면 산동리', '거래금액': '5,900', '전용면적': '39.73', '층': '5', '건축년도': '1997'}, {'아파트명': '아산반도유보라', '법정동': '온천동', '거래금액': '19,300', '전용면적': '59.9734', '층': '15', '건축년도': '2016'}, {'아파트명': '서해그랑블2차', '법정동': '권곡동', '거래금액': '21,000', '전용면적': '84.4973', '층': '13', '건축년도': '2009'}, {'아파트명': '샘마을', '법정동': '신창면 남성리', '거래금액': '4,100', '전용면적': '39.27', '층': '12', '건축년도': '2001'}, {'아파트명': '아산온천미소지움아파트', '법정동': '온천동', '거래금액': '21,000', '전용면적': '74.9754', '층': '2', '건축년도': '2017'}, {'아파트명': '모종캐슬어울림3단지', '법정동': '모종동', '거래금액': '33,000', '전용면적': '84.972', '층': '6', '건축년도': '2017'}]

# %%
import pandas as pd
df = pd.DataFrame(atm_data)

# %%
file_name = f'data/아산_아파트매매실거래_202604월'
df.to_csv(f'{file_name}.csv')

# %%
import requests
import xmltodict
import pandas as pd


url = 'https://apis.data.go.kr/1613000/RTMSDataSvcAptTrade/getRTMSDataSvcAptTrade'
params = {
    'LAWD_CD': '44200',
     'DEAL_YMD' : '202604',
     'serviceKey' : '       }

response = requests.get(url, params=params)
response.status_code

response_data = xmltodict.parse(response.content)
response_data
items = response_data['response']['body']['items']['item'] 

atm_data = []

for item in items:
   
    atm_data.append({"아파트명" : item['aptNm'], "법정동" : item['umdNm'], "거래금액" : item['dealAmount'], "전용면적" : item["excluUseAr"],"층" : item["floor"],"건축년도" : item['buildYear']})

print(atm_data)

df = pd.DataFrame(atm_data)

file_name = f'data/아산_아파트매매실거래_202604월'
df.to_csv(f'{file_name}.csv')
